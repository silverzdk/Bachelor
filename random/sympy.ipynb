# %% [markdown]
# Heat Transfer in Single and Multiphase Systems
# eq 10.69

# %%
import sympy as sp 
import sympy.physics.units as u

d_i, d_o, h_h, h_c = sp.symbols('d_i d_o h_h h_c')

U_I = (1/h_c + d_i/(d_o*h_h))**-1
display(U_I)

U_I.subs({d_i:0.0508*u.m, d_o:0.0603*u.m, h_h:7953*u.W/u.m**2/u.K, h_c:123*u.W/u.m**2/u.K})
# Out:
# 1/(d_i/(d_o*h_h) + 1/h_c)
# 121.418010338518*watt/(kelvin*meter**2)

# %%
m_dot = 0.1 * u.kg / u.s
inner_diameter = 0.05 * u.m
density = 1000 * u.kg / u.m**3

vel = m_dot / (density * (sp.pi * (inner_diameter / 2)**2))
display(vel.evalf(3))
# Out:
# 0.0509*meter/second

# %%
x = sp.symbols('x')
func = (sp.tanh(x)/x)

sp.plot(func, (x, 0.01, 5))

# %%
1.5 * 0.5
# Out:
# 0.75
