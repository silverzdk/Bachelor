# %% [markdown]
# Importing main script

# %%
import sys
sys.path.append('../src')

# Import the module to be reloaded
import Simple_Model_r0
import importlib
importlib.reload(Simple_Model_r0)

# Import everything from the r<eloaded module
from Simple_Model_r0 import *

# %% [markdown]
# ### Example usage

# %% [markdown]
# #### Example of Node

# %%
geom = Geometry(
    # Height and length of the heat exchanger
    width=1,
    length=1,
    # Pipe dimensions
    pipe_outer_diameter=0.0603, 
    pipe_wall_thickness=0.005,
    # Arrengement dimensions
    arrangement="Inline", 
    transverse_pitch=0.04, 
    longitudinal_pitch=0.04
    )

node1 = Node(
        Geometry=geom,
        x_pos=0,
        node_length=0.1, #m
        T_hot_init=343, # C 
        T_cold_init=200, # C 
        P_hot_init=158e5, # Pa
        P_cold_init=1e5, # Pa
        m_dot_hot=6, # kg/s
        m_dot_cold=50, # kg/s
        is_boundary=True
    )
node1.Fluid_hot.update(Input.pressure(158e5), Input.enthalpy(node1.Fluid_hot.dew_point_at_pressure(158e5).enthalpy))

print(node1.Fluid_hot.quality)

Delta_H = node1.overall_HTC()

for i in range(11):
    node1.Fluid_hot.update(Input.enthalpy(node1.Fluid_hot.enthalpy + Delta_H), Input.pressure(158e5))
    Delta_H = node1.overall_HTC()
    print(f"--{i}-- x: {node1.Fluid_hot.quality}, Delta_H: {Delta_H}")
# Out:
# 0.9999999999999996
# --0-- x: 0.999993975471026, Delta_H: -5.714001911509895
# --1-- x: 0.9999879306405225, Delta_H: -5.71434428504172
# --2-- x: 0.9999818854478232, Delta_H: -5.714540078403971
# --3-- x: 0.9999758400479944, Delta_H: -5.7146770689734785
# --4-- x: 0.9999697945032436, Delta_H: -5.714782250988063
# --5-- x: 0.9999637488472208, Delta_H: -5.714867504493112
# --6-- x: 0.9999577031010087, Delta_H: -5.71493910981041
# --7-- x: 0.9999516572790454, Delta_H: -5.715000788665157
# --8-- x: 0.9999456113918321, Delta_H: -5.715054927106488
# --9-- x: 0.9999395654473457, Delta_H: -5.715103145802939
# --10-- x: 0.9999335194518492, Delta_H: -5.715146595401099

# %%
node1.Fluid_hot.enthalpy
# Out:
# np.float64(2486986.971158381)

# %% [markdown]
# #### Example of fluid class

# %%
geom = Geometry(
    # Height and length of the heat exchanger
    width=1,
    length=1,
    # Pipe dimensions
    pipe_outer_diameter=0.025, 
    pipe_wall_thickness=0.002,
    # Arrengement dimensions
    arrangement="Staggered", 
    transverse_pitch=0.04, 
    longitudinal_pitch=0.04
    )

# Define the fluid (water in this case)
water = Fluid(FluidsList.Water,10)

# Set the state 
water.update(Input.enthalpy(430340.09), Input.pressure(158e5))  # 1 bar = 100000 Pa

water.set_geometry(geom, 'internal')
print(water.units_system)
water.dynamic_viscosity

print(water.liquid_phase().enthalpy)
print(water.vapor_phase().enthalpy)
# Out:
# SIWithCelsius
# 419057.7330939922
# 2675529.32550072

# %%
pf.config
# Out:
# <module 'pyfluids.config' from 'c:\\Users\\nausk\\anaconda3\\envs\\DTU\\Lib\\site-packages\\pyfluids\\config\\__init__.py'>
