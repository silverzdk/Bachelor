# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys
sys.path.insert(0, '../src')

from Classes import Fluid, Geometry

from pyfluids import FluidsList, Input

# %% [markdown]
# Fluegas

# %%
m_dot = 62.917  
Air = Fluid(FluidsList.Air,m_dot)

T_in = 230 # Celsius
P_in = (-4e3) + 966e2 

Air.update(Input.temperature(T_in), Input.pressure(P_in))

Bank = Geometry( 
                pipe_outer_diameter=26.9e-3,
                pipe_wall_thickness=1.5e-3,
                transverse_pitch=,
                longitudinal_pitch=,,
                arrangement='staggered',
                number_of_rows=,
                
                )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 9
#       5 P_in = (-4e3) + 966e2
#       7 Air.update(Input.temperature(T_in), Input.pressure(P_in))
# ----> 9 Bank = Geometry(
#      10                 pipe_outer_diameter=26.9e-3,
#      11                 pipe_wall_thickness=1.5e-3,
#      12
#      13                 )
#
# TypeError: Geometry.__init__() missing 4 required positional arguments: 'width', 'length', 'transverse_pitch', and 'longitudinal_pitch'

# %% [markdown]
# Steam

# %%
x = 1

match x:
    case 1:
        print("x is 1")
    case 2 |3:
        print("x is 2 or 3")
    case _:
        print("x is something else")
# Out:
# x is 1
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
